# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/valen/code/VaHerinckx/LifeLog_Project/lifelog_python_processing/files/exports/offscreen_exports/Pickup.csv").sort_values("start", ascending = False)

# %%
pd.set_option('display.max_rows', 1000)  # Show up to 100 rows

# %%
df = pd.read_csv("/Users/valen/code/VaHerinckx/LifeLog_Project/lifelog_python_processing/files/processed_files/screentime/offscreen_processed.csv", sep = '|')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date                            object
# screen_time                    float64
# pickups                        float64
# within_hour_before_sleep         int64
# sleep_start_timestamp_local    float64
# dtype: object

# %%
df_nov9 = df[df['date'].dt.date == pd.to_datetime('2025-11-09').date()]

# %%
df_nov9
# Out:
#                    date  screen_time  pickups  within_hour_before_sleep  \
# 166 2025-11-09 21:42:00          3.0      0.0                         0
# 167 2025-11-09 21:41:00         23.0      1.0                         0
# 168 2025-11-09 21:28:00         38.0      0.0                         0
# 169 2025-11-09 21:27:00         60.0      0.0                         0
# 170 2025-11-09 21:26:00         60.0      0.0                         0
# 171 2025-11-09 21:25:00         60.0      0.0                         0
# 172 2025-11-09 21:24:00         60.0      0.0                         0
# 173 2025-11-09 21:23:00         60.0      0.0                         0
# 174 2025-11-09 21:22:00         60.0      0.0                         0
# 175 2025-11-09 21:21:00         60.0      0.0                         0
# 176 2025-11-09 21:20:00         60.0      0.0                         0
# 177 2025-11-09 21:19:00         60.0      0.0                         0
# ...
